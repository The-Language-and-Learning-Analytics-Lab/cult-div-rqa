# %%
import pandas as pd

# %%
data = pd.read_csv('/Users/amin/Downloads/Master Coded Data.xlsx - Chats.csv')

# %%
data.columns
# Out:
# Index(['task', 'team_id', 'Person-ID (mellon-ID)', 'event_start_time',
#        'event_end_time', 'event_result', 'Primary code ', 'Primary Sub-code',
#        'Secondary Code', 'Secondary  Sub-code', 'Apartment Feature 1',
#        'Apartment Feature 2', 'Apartment Feature 3', 'Apartment Feature 4 ',
#        'Candidate Feature 1', 'Candidate Feature 2', 'Candidate Feature 3',
#        'Candidate Feature 4', 'Party Venue Feature 1', 'Party Venue Feature 2',
#        'Party Venue Feature 3', 'Party Venue Feature 4', 'Professor Feature 1',
#        'Professor Feature 2', 'Professor Feature 3', 'Professor Feature 4'],
#       dtype='object')

# %%
data.team_id.unique()[0]
# Out:
# '179706_162850_162936_182908'

# %%
data[data.team_id == data.team_id.unique()[0]]['Primary Sub-code']
# Out:
# 0      SMC-R
# 1      SMC-R
# 2      SMC-R
# 3      SMC-R
# 4       CM-G
#        ...
# 77     SMC-R
# 78    SESU-A
# 79     SMC-R
# 80     SMC-R
# 81     SMC-R
# Name: Primary Sub-code, Length: 82, dtype: object

# %%
from numpy import asarray
from sklearn.preprocessing import LabelEncoder
# define data
a = data['Primary code ']
# define one hot encoding
encoder = LabelEncoder()
# transform data
encoder.fit(a)
print(encoder.transform(data[data.team_id == data.team_id.unique()[0]]['Primary code ']))
# Out:
# [6 6 6 6 1 8 6 5 0 8 0 6 6 5 5 8 8 8 8 3 3 8 5 8 8 8 7 8 7 8 8 8 8 8 8 5 8
#  5 8 0 8 0 7 7 0 8 8 8 8 8 8 8 0 8 8 8 8 8 1 7 8 8 8 7 8 5 5 1 8 1 8 5 7 0
#  6 7 6 6 5 6 6 6]

# %%
len(data['Person-ID (mellon-ID)'].unique())
# Out:
# 537

# %%
scores = pd.read_csv('/Users/amin/Downloads/CPS_scores.csv')

# %%
data = data.rename(columns={'Person-ID (mellon-ID)' : 'mellon_id'})

# %%
data
# Out:
#            task                      team_id mellon_id  \
# 0     apartment  179706_162850_162936_182908    162850
# 1     apartment  179706_162850_162936_182908    182908
# 2     apartment  179706_162850_162936_182908    162936
# 3     apartment  179706_162850_162936_182908    179706
# 4     apartment  179706_162850_162936_182908    162850
# ...         ...                          ...       ...
# 7706  Candidate  190690_163721_178949_190068    186557
# 7707  Candidate  190690_163721_178949_190069    186557
# 7708  Candidate  190690_163721_178949_190070    165170
# 7709  Candidate  190690_163721_178949_190071    190696
# 7710  Candidate  190690_163721_178949_190072    183614
#
#                event_start_time             event_end_time       event_result  \
# 0     2019-09-28 17:14:21+00:00  2019-09-28 17:14:21+00:00                 Hi
# 1     2019-09-28 17:14:39+00:00  2019-09-28 17:14:39+00:00                hey
# 2     2019-09-28 17:14:47+00:00  2019-09-28 17:14:47+00:00                Hey
# 3     2019-09-28 17:14:48+00:00  2019-09-28 17:14:48+00:00               hola
# 4     2019-09-28 17:14:56+00:00  2019-09-28 17:14:56+00:00  Is everyone here?
# ...                         ...                        ...                ...
# 7706  2019-10-01 23:38:41+00:00                        NaN                 so
# 7707  2019-10-01 23:38:43+00:00                        NaN               CBA?
# 7708  2019-10-01 23:38:46+00:00                        NaN               yeah
# 7709  2019-10-01 23:38:48+00:00                        NaN       I believe so
# 7710  2019-10-01 23:38:53+00:00                        NaN             yes :)
#
#      Primary code  Primary Sub-code Secondary Code Secondary  Sub-code  ...  \
# 0              SMC            SMC-R            NaN                 NaN  ...
# 1              SMC            SMC-R            NaN                 NaN  ...
# 2              SMC            SMC-R            NaN                 NaN  ...
# 3              SMC            SMC-R            NaN                 NaN  ...
# 4               CM             CM-G            NaN                 NaN  ...
# ...            ...              ...            ...                 ...  ...
# 7706           SSI            SSI-U            NaN                 NaN  ...
# 7707            CM             CM-S            NaN                 NaN  ...
# 7708            SN             SN-A            NaN                 NaN  ...
# 7709          SESU           SESU-A            NaN                 NaN  ...
# 7710            SN             SN-A            NaN                 NaN  ...
#
#      Candidate Feature 3 Candidate Feature 4 Party Venue Feature 1  \
# 0                    NaN                 NaN                   NaN
# 1                    NaN                 NaN                   NaN
# 2                    NaN                 NaN                   NaN
# 3                    NaN                 NaN                   NaN
# 4                    NaN                 NaN                   NaN
# ...                  ...                 ...                   ...
# 7706                 NaN                 NaN                   NaN
# 7707                 NaN                 NaN                   NaN
# 7708                 NaN                 NaN                   NaN
# 7709                 NaN                 NaN                   NaN
# 7710                 NaN                 NaN                   NaN
#
#      Party Venue Feature 2 Party Venue Feature 3 Party Venue Feature 4  \
# 0                      NaN                   NaN                   NaN
# 1                      NaN                   NaN                   NaN
# 2                      NaN                   NaN                   NaN
# 3                      NaN                   NaN                   NaN
# 4                      NaN                   NaN                   NaN
# ...                    ...                   ...                   ...
# 7706                   NaN                   NaN                   NaN
# 7707                   NaN                   NaN                   NaN
# 7708                   NaN                   NaN                   NaN
# 7709                   NaN                   NaN                   NaN
# 7710                   NaN                   NaN                   NaN
#
#      Professor Feature 1 Professor Feature 2 Professor Feature 3  \
# 0                    NaN                 NaN                 NaN
# 1                    NaN                 NaN                 NaN
# 2                    NaN                 NaN                 NaN
# 3                    NaN                 NaN                 NaN
# 4                    NaN                 NaN                 NaN
# ...                  ...                 ...                 ...
# 7706                 NaN                 NaN                 NaN
# 7707                 NaN                 NaN                 NaN
# 7708                 NaN                 NaN                 NaN
# 7709                 NaN                 NaN                 NaN
# 7710                 NaN                 NaN                 NaN
#
#      Professor Feature 4
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 7706                 NaN
# 7707                 NaN
# 7708                 NaN
# 7709                 NaN
# 7710                 NaN
#
# [7711 rows x 26 columns]

# %%
data_score = data.merge(scores, on=['mellon_id'], how = 'inner')

# %%
data_score
# Out:
#          task_x                      team_id mellon_id  \
# 0     apartment  179706_162850_162936_182908    162850
# 1     apartment  179706_162850_162936_182908    162850
# 2     apartment  179706_162850_162936_182908    162850
# 3     apartment  179706_162850_162936_182908    162850
# 4     apartment  179706_162850_162936_182908    162850
# ...         ...                          ...       ...
# 7757  Candidate  190690_163721_178949_190053    165170
# 7758  Candidate  190690_163721_178949_190054    165170
# 7759  Candidate  190690_163721_178949_190058    165170
# 7760  Candidate  190690_163721_178949_190065    165170
# 7761  Candidate  190690_163721_178949_190070    165170
#
#                event_start_time             event_end_time  \
# 0     2019-09-28 17:14:21+00:00  2019-09-28 17:14:21+00:00
# 1     2019-09-28 17:14:56+00:00  2019-09-28 17:14:56+00:00
# 2     2019-09-28 17:15:44+00:00  2019-09-28 17:15:44+00:00
# 3     2019-09-28 17:21:04+00:00  2019-09-28 17:21:04+00:00
# 4     2019-09-28 17:21:30+00:00  2019-09-28 17:21:30+00:00
# ...                         ...                        ...
# 7757  2019-10-01 23:36:06+00:00                        NaN
# 7758  2019-10-01 23:36:16+00:00                        NaN
# 7759  2019-10-01 23:37:05+00:00                        NaN
# 7760  2019-10-01 23:38:35+00:00                        NaN
# 7761  2019-10-01 23:38:46+00:00                        NaN
#
#                                            event_result Primary code   \
# 0                                                    Hi           SMC
# 1                                     Is everyone here?            CM
# 2             Lets wait to see what the instructor says            CE
# 3                                                   Hey           SMC
# 4                                                 A B C           SSI
# ...                                                 ...           ...
# 7757                                            o snaap           SMC
# 7758                       im shook can yall post yours            CE
# 7759  wait it is suppose to be this way or is it a g...           SSI
# 7760  I think w/ the new info, I think C is better t...           SSI
# 7761                                               yeah            SN
#
#      Primary Sub-code Secondary Code Secondary  Sub-code  ...  \
# 0               SMC-R            NaN                 NaN  ...
# 1                CM-G            NaN                 NaN  ...
# 2               CEC-S            NaN                 NaN  ...
# 3               SMC-R            NaN                 NaN  ...
# 4               SSI-O            NaN                 NaN  ...
# ...               ...            ...                 ...  ...
# 7757            SMC-R            NaN                 NaN  ...
# 7758            CEC-S            NaN                 NaN  ...
# 7759            SSI-U            NaN                 NaN  ...
# 7760            SSI-O            NaN                 NaN  ...
# 7761             SN-A            NaN                 NaN  ...
#
#      Professor Feature 2 Professor Feature 3 Professor Feature 4 initial  \
# 0                    NaN                 NaN                 NaN     ABC
# 1                    NaN                 NaN                 NaN     ABC
# 2                    NaN                 NaN                 NaN     ABC
# 3                    NaN                 NaN                 NaN     ABC
# 4                    NaN                 NaN                 NaN     ABC
# ...                  ...                 ...                 ...     ...
# 7757                 NaN                 NaN                 NaN     BAC
# 7758                 NaN                 NaN                 NaN     BAC
# 7759                 NaN                 NaN                 NaN     BAC
# 7760                 NaN                 NaN                 NaN     BAC
# 7761                 NaN                 NaN                 NaN     BAC
#
#      revise      session_id     task_y ini_score revise_score score_change
# 0       ABC  7351_apartment  apartment         0            1            1
# 1       ABC  7351_apartment  apartment         0            1            1
# 2       ABC  7351_apartment  apartment         0            1            1
# 3       ABC  7351_apartment  apartment         0            1            1
# 4       ABC  7351_apartment  apartment         0            1            1
# ...     ...             ...        ...       ...          ...          ...
# 7757    CBA  7367_candidate  candidate         1            0           -1
# 7758    CBA  7367_candidate  candidate         1            0           -1
# 7759    CBA  7367_candidate  candidate         1            0           -1
# 7760    CBA  7367_candidate  candidate         1            0           -1
# 7761    CBA  7367_candidate  candidate         1            0           -1
#
# [7762 rows x 33 columns]

# %%
d1 = data_score.groupby(by=['team_id', 'mellon_id'], as_index=False).agg({'revise_score': 'mean'})

# %%
d2 = d1.groupby(by=['team_id'], as_index=False).agg({'revise_score': 'mean'})

# %%
d3 = data_score[['task_x', 'team_id', 'mellon_id', 'Primary code ']].merge(d2, on = ['team_id'])

# %%
np.mean(scores['revise_score'])
# Out:
# 0.40671641791044777

# %%
mean = np.mean(d3['revise_score'])
high_perf = (d3['revise_score'] > mean).astype(int)

# %%
d3['high_performance'] = high_perf

# %%
d3
# Out:
#          task_x                      team_id mellon_id Primary code   \
# 0     apartment  179706_162850_162936_182908    162850           SMC
# 1     apartment  179706_162850_162936_182908    162850            CM
# 2     apartment  179706_162850_162936_182908    162850            CE
# 3     apartment  179706_162850_162936_182908    162850           SMC
# 4     apartment  179706_162850_162936_182908    162850           SSI
# ...         ...                          ...       ...           ...
# 7757  Candidate  190690_163721_178949_190053    165170           SMC
# 7758  Candidate  190690_163721_178949_190054    165170            CE
# 7759  Candidate  190690_163721_178949_190058    165170           SSI
# 7760  Candidate  190690_163721_178949_190065    165170           SSI
# 7761  Candidate  190690_163721_178949_190070    165170            SN
#
#       revise_score  high_performance
# 0              1.0                 1
# 1              1.0                 1
# 2              1.0                 1
# 3              1.0                 1
# 4              1.0                 1
# ...            ...               ...
# 7757           0.0                 0
# 7758           0.0                 0
# 7759           0.0                 0
# 7760           0.0                 0
# 7761           0.0                 0
#
# [7762 rows x 6 columns]

# %%
d3.to_csv('codes_scores_merged.csv')

# %%
data_merged = pd.read_csv('codes_scores_merged.csv')

# %%
background = pd.read_csv('Mellondemographic_Student_20200205.csv')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3155: DtypeWarning: Columns (5,13,14,16,18,170) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
background['ethnicity'].unique()
# Out:
# array(['Hispanic', 'Asian / Asian American', 'White, non-Hispanic',
#        'International student', 'Two or more ethnicities, with URM',
#        'Black, non-Hispanic', 'Two or more ethnicities',
#        'Unknown / declined to state', 'Unknown',
#        'American Indian / Alaskan Native', 'Pacific Islander'],
#       dtype=object)

# %%
background.gender.unique()
# Out:
# array(['M', 'F', 'U', 'MD', 'BD'], dtype=object)

# %%
data_merged
# Out:
#       Unnamed: 0     task_x                      team_id mellon_id  \
# 0              0  apartment  179706_162850_162936_182908    162850
# 1              1  apartment  179706_162850_162936_182908    162850
# 2              2  apartment  179706_162850_162936_182908    162850
# 3              3  apartment  179706_162850_162936_182908    162850
# 4              4  apartment  179706_162850_162936_182908    162850
# ...          ...        ...                          ...       ...
# 7757        7757  Candidate  190690_163721_178949_190053    165170
# 7758        7758  Candidate  190690_163721_178949_190054    165170
# 7759        7759  Candidate  190690_163721_178949_190058    165170
# 7760        7760  Candidate  190690_163721_178949_190065    165170
# 7761        7761  Candidate  190690_163721_178949_190070    165170
#
#      Primary code   revise_score  high_performance
# 0              SMC           1.0                 1
# 1               CM           1.0                 1
# 2               CE           1.0                 1
# 3              SMC           1.0                 1
# 4              SSI           1.0                 1
# ...            ...           ...               ...
# 7757           SMC           0.0                 0
# 7758            CE           0.0                 0
# 7759           SSI           0.0                 0
# 7760           SSI           0.0                 0
# 7761            SN           0.0                 0
#
# [7762 rows x 7 columns]

# %%
female = []
fm = []
non_int = ['wendy6', 'Ratlife2001', 'Isabella', 'juarezm', 'jennajyee', 'Santa@na2019', 'ucinetid', 'zotzot', 'C@ss3tte']
for i in data_merged.team_id:
    s = 0
    members = i.split('_')
    for j in members:
        if j in non_int:
            continue
        g = background[background.mellon_id == int(j)]['gender'].any()
        if g == 'F':
            s += 1
    female.append(s)
    fm.append(int(s>(len(members)/2)))

# %%
data_merged['female_members'] = female

# %%
data_merged['female_maj'] = fm

# %%
data_merged.to_csv('codes_scores_gender_merged.csv')

# %%
data = pd.read_csv('codes_scores_gender_merged.csv')

# %%
data
# Out:
#       Unnamed: 0  Unnamed: 0.1     task_x                      team_id  \
# 0              0             0  apartment  179706_162850_162936_182908
# 1              1             1  apartment  179706_162850_162936_182908
# 2              2             2  apartment  179706_162850_162936_182908
# 3              3             3  apartment  179706_162850_162936_182908
# 4              4             4  apartment  179706_162850_162936_182908
# ...          ...           ...        ...                          ...
# 7757        7757          7757  Candidate  190690_163721_178949_190053
# 7758        7758          7758  Candidate  190690_163721_178949_190054
# 7759        7759          7759  Candidate  190690_163721_178949_190058
# 7760        7760          7760  Candidate  190690_163721_178949_190065
# 7761        7761          7761  Candidate  190690_163721_178949_190070
#
#      mellon_id Primary code   revise_score  high_performance  female_members  \
# 0       162850           SMC           1.0                 1               2
# 1       162850            CM           1.0                 1               2
# 2       162850            CE           1.0                 1               2
# 3       162850           SMC           1.0                 1               2
# 4       162850           SSI           1.0                 1               2
# ...        ...           ...           ...               ...             ...
# 7757    165170           SMC           0.0                 0               3
# 7758    165170            CE           0.0                 0               3
# 7759    165170           SSI           0.0                 0               3
# 7760    165170           SSI           0.0                 0               3
# 7761    165170            SN           0.0                 0               4
#
#       female_maj
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 7757           1
# 7758           1
# 7759           1
# 7760           1
# 7761           1
#
# [7762 rows x 10 columns]

# %%
data.merge(background[['mellon_id', 'gender', 'ethnicity']], on = 'mellon_id', how = 'left').to_csv('data_gender_ethnicity_merged.csv')

# %%
background[['mellon_id', 'gender']]
# Out:
#        mellon_id gender
# 0         179662      M
# 1         164578      F
# 2         184770      F
# 3         185333      F
# 4         187436      F
# ...          ...    ...
# 37300     188769      F
# 37301     184973      M
# 37302     185337      F
# 37303     163103      F
# 37304     182223      M
#
# [37305 rows x 2 columns]

# %%
data.mellon_id = data.mellon_id.astype(str)
background.mellon_id = background.mellon_id.astype(str)

# %%
data
# Out:
#       Unnamed: 0  Unnamed: 0.1     task_x                      team_id  \
# 0              0             0  apartment  179706_162850_162936_182908
# 1              1             1  apartment  179706_162850_162936_182908
# 2              2             2  apartment  179706_162850_162936_182908
# 3              3             3  apartment  179706_162850_162936_182908
# 4              4             4  apartment  179706_162850_162936_182908
# ...          ...           ...        ...                          ...
# 7757        7757          7757  Candidate  190690_163721_178949_190053
# 7758        7758          7758  Candidate  190690_163721_178949_190054
# 7759        7759          7759  Candidate  190690_163721_178949_190058
# 7760        7760          7760  Candidate  190690_163721_178949_190065
# 7761        7761          7761  Candidate  190690_163721_178949_190070
#
#      mellon_id Primary code   revise_score  high_performance  female_members  \
# 0       162850           SMC           1.0                 1               2
# 1       162850            CM           1.0                 1               2
# 2       162850            CE           1.0                 1               2
# 3       162850           SMC           1.0                 1               2
# 4       162850           SSI           1.0                 1               2
# ...        ...           ...           ...               ...             ...
# 7757    165170           SMC           0.0                 0               3
# 7758    165170            CE           0.0                 0               3
# 7759    165170           SSI           0.0                 0               3
# 7760    165170           SSI           0.0                 0               3
# 7761    165170            SN           0.0                 0               4
#
#       female_maj
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 7757           1
# 7758           1
# 7759           1
# 7760           1
# 7761           1
#
# [7762 rows x 10 columns]
