# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('./data/final.csv')

# %%
data.head()
# Out:
#    Unnamed: 0       session_id mellon_id  \
# 0           0  7298_PartyVenue    173442
# 1           1  7298_PartyVenue    173442
# 2           2  7298_PartyVenue    173442
# 3           3  7298_PartyVenue    173442
# 4           4  7298_PartyVenue    173442
#
#                                            player_id  \
# 0  {'userID1': '202618', 'nickname1': 'bean boi',...
# 1  {'userID1': '202618', 'nickname1': 'bean boi',...
# 2  {'userID1': '202618', 'nickname1': 'bean boi',...
# 3  {'userID1': '202618', 'nickname1': 'bean boi',...
# 4  {'userID1': '202618', 'nickname1': 'bean boi',...
#
#                                         event_result        task  \
# 0                                     what's up lads  PartyVenue
# 1                            bean boi i like ur name  PartyVenue
# 2                                also mood alice lol  PartyVenue
# 3  question when u guys were signing up on the su...  PartyVenue
# 4                             RIGHT? ok im not crazy  PartyVenue
#
#   Primary code   revise_score  high_performance  female_members  female_maj  \
# 0           SMC           0.0                 0               4           1
# 1           SMC           0.0                 0               4           1
# 2           SMC           0.0                 0               4           1
# 3           SMC           0.0                 0               4           1
# 4           SMC           0.0                 0               4           1
#
#   gender                    ethnicity application_status  first_generation  \
# 0      F  Unknown / declined to state          Sophomore               0.0
# 1      F  Unknown / declined to state          Sophomore               0.0
# 2      F  Unknown / declined to state          Sophomore               0.0
# 3      F  Unknown / declined to state          Sophomore               0.0
# 4      F  Unknown / declined to state          Sophomore               0.0
#
#    urm first_language
# 0  0.0   English only
# 1  0.0   English only
# 2  0.0   English only
# 3  0.0   English only
# 4  0.0   English only

# %%
len(data.mellon_id.unique())
# Out:
# 514

# %%
len(data.session_id.unique())
# Out:
# 129

# %% [markdown]
# # Code frequencies

# %%
data['Primary code '].value_counts()
# Out:
# SSI     2638
# SESU    1209
# SMC     1166
# SN       875
# CRF      597
# CE       440
# CM       390
# CP        38
# TD         8
# EM         7
# Name: Primary code , dtype: int64

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_axes([0,0,1,1])
k = data['Primary code '].value_counts().index
val = data['Primary code '].value_counts()
sns.barplot(k, val)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Female majority

# %%
data.groupby(['session_id']).female_maj.max().value_counts()
# Out:
# 1    81
# 0    48
# Name: female_maj, dtype: int64

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_axes([0,0,1,1])
k = data.groupby(['session_id']).female_maj.max().value_counts().index
val = data.groupby(['session_id']).female_maj.max().value_counts()
sns.barplot(k, val)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Race

# %%
data.groupby(['mellon_id']).ethnicity.max().value_counts()
# Out:
# Asian / Asian American               209
# Hispanic                             162
# White, non-Hispanic                   62
# International student                 33
# Unknown                               12
# Two or more ethnicities, with URM      9
# Black, non-Hispanic                    9
# Unknown / declined to state            5
# Pacific Islander                       1
# Name: ethnicity, dtype: int64

# %%
[x/514 for x in data.groupby(['mellon_id']).ethnicity.max().value_counts()]
# Out:
# [0.4066147859922179,
#  0.3151750972762646,
#  0.12062256809338522,
#  0.06420233463035019,
#  0.023346303501945526,
#  0.017509727626459144,
#  0.017509727626459144,
#  0.009727626459143969,
#  0.0019455252918287938]

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_axes([0,0,1,1])
k = data.groupby(['mellon_id']).ethnicity.max().value_counts().index
val = data.groupby(['mellon_id']).ethnicity.max().value_counts()
sns.barplot(k, val)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Gender

# %%
data.groupby(['mellon_id']).gender.max().value_counts()
# Out:
# F    347
# M    155
# Name: gender, dtype: int64

# %%
fig = plt.figure(figsize=(7,10))
ax = fig.add_axes([0,0,1,1])
k = data.groupby(['mellon_id']).gender.max().value_counts().index
val = data.groupby(['mellon_id']).gender.max().value_counts()
sns.barplot(k, val)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Year

# %%
data.groupby(['mellon_id']).application_status.max().value_counts()
# Out:
# Freshman     342
# Junior       128
# Sophomore     24
# Senior         8
# Name: application_status, dtype: int64

# %%
fig = plt.figure(figsize=(7,5))
ax = fig.add_axes([0,0,1,1])
k = data.groupby(['mellon_id']).application_status.max().value_counts().index
val = data.groupby(['mellon_id']).application_status.max().value_counts()
sns.barplot(k, val)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # First generation

# %%
data.groupby(['mellon_id']).first_generation.max().value_counts()
# Out:
# 1.0    277
# 0.0    225
# Name: first_generation, dtype: int64

# %%
fig = plt.figure(figsize=(7,5))
ax = fig.add_axes([0,0,1,1])
k = ['first generation', 'non-first generation']
val = data.groupby(['mellon_id']).first_generation.max().value_counts()
sns.barplot(k, val)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Scores

# %%
data.groupby(['mellon_id']).revise_score.mean().value_counts()
# Out:
# 0.000    343
# 1.000     56
# 2.000     52
# 0.500     16
# 1.500     12
# 1.750     12
# 0.250      8
# 0.125      7
# 1.250      4
# 0.750      4
# Name: revise_score, dtype: int64

# %%
fig = plt.figure(figsize=(5,7))
ax = fig.add_axes([0,0,1,1])
k = list(data.groupby(['mellon_id']).revise_score.max().value_counts().index)
val = list(data.groupby(['mellon_id']).revise_score.max().value_counts())
sns.barplot(k, val)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.histplot(list(data.groupby(['mellon_id']).revise_score.max()))
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.histplot([len(x) for x in data.groupby(['session_id']).ethnicity.unique()])
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
fig = plt.figure(figsize=(5,3))
ax = fig.add_axes([0,0,1,1])
k = ['2', '3', '4', '5', '6', '7', '8']
val = [0, 2, 0, 0, 0, 0, 1]
sns.barplot(k, val)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
from scipy.stats import entropy

# %%
entropy([0, 2, 0, 0, 0, 0, 1])
# Out:
# 0.6365141682948128

# %%
entropy([1, 2, 2, 3, 1, 3, 1])
# Out:
# 1.844621476365503

# %%
diversity = data.groupby(['session_id']).ethnicity.unique()

# %%
diversity
# Out:
# session_id
# 7283_Professor             [White, non-Hispanic, Hispanic, Unknown]
# 7285_Professor        [Asian / Asian American, White, non-Hispanic]
# 7287_Professor    [White, non-Hispanic, Asian / Asian American, ...
# 7288_Professor    [Asian / Asian American, Unknown, Hispanic, In...
# 7289_Professor                                           [Hispanic]
#                                         ...
# 7376_apartment    [White, non-Hispanic, Unknown / declined to st...
# 7377_apartment    [Asian / Asian American, White, non-Hispanic, ...
# 7378_apartment    [Asian / Asian American, Hispanic, Black, non-...
# 7380_apartment    [Two or more ethnicities, with URM, White, non...
# 7388_apartment      [Asian / Asian American, International student]
# Name: ethnicity, Length: 129, dtype: object

# %%
data = data.merge(diversity, on = ['session_id'], how= 'left')

# %%
data['diversity'] = [len(a) for a in data['ethnicity_y']]

# %%
data
# Out:
#       Unnamed: 0       session_id mellon_id  \
# 0              0  7298_PartyVenue    173442
# 1              1  7298_PartyVenue    173442
# 2              2  7298_PartyVenue    173442
# 3              3  7298_PartyVenue    173442
# 4              4  7298_PartyVenue    173442
# ...          ...              ...       ...
# 7363        7363   7371_candidate    187876
# 7364        7364   7371_candidate    187876
# 7365        7365   7371_candidate    187876
# 7366        7366   7371_candidate    187876
# 7367        7367   7371_candidate    187876
#
#                                               player_id  \
# 0     {'userID1': '202618', 'nickname1': 'bean boi',...
# 1     {'userID1': '202618', 'nickname1': 'bean boi',...
# 2     {'userID1': '202618', 'nickname1': 'bean boi',...
# 3     {'userID1': '202618', 'nickname1': 'bean boi',...
# 4     {'userID1': '202618', 'nickname1': 'bean boi',...
# ...                                                 ...
# 7363  {'userID1': '187876', 'nickname1': 'Sabrina', ...
# 7364  {'userID1': '187876', 'nickname1': 'Sabrina', ...
# 7365  {'userID1': '187876', 'nickname1': 'Sabrina', ...
# 7366  {'userID1': '187876', 'nickname1': 'Sabrina', ...
# 7367  {'userID1': '187876', 'nickname1': 'Sabrina', ...
#
#                                            event_result        task  \
# 0                                        what's up lads  PartyVenue
# 1                               bean boi i like ur name  PartyVenue
# 2                                   also mood alice lol  PartyVenue
# 3     question when u guys were signing up on the su...  PartyVenue
# 4                                RIGHT? ok im not crazy  PartyVenue
# ...                                                 ...         ...
# 7363                   I put BCA what did you guys put?   candidate
# 7364                                                yes   candidate
# 7365                                               yeah   candidate
# 7366  A has fewer character qualities than the other...   candidate
# 7367                      we can then all agree on BCA?   candidate
#
#      Primary code   revise_score  high_performance  female_members  \
# 0              SMC           0.0                 0               4
# 1              SMC           0.0                 0               4
# 2              SMC           0.0                 0               4
# 3              SMC           0.0                 0               4
# 4              SMC           0.0                 0               4
# ...            ...           ...               ...             ...
# 7363           SSI           0.0                 0               3
# 7364          SESU           0.0                 0               3
# 7365            SN           0.0                 0               3
# 7366           SSI           0.0                 0               3
# 7367            CM           0.0                 0               3
#
#       female_maj gender                  ethnicity_x application_status  \
# 0              1      F  Unknown / declined to state          Sophomore
# 1              1      F  Unknown / declined to state          Sophomore
# 2              1      F  Unknown / declined to state          Sophomore
# 3              1      F  Unknown / declined to state          Sophomore
# 4              1      F  Unknown / declined to state          Sophomore
# ...          ...    ...                          ...                ...
# 7363           1      F                     Hispanic             Junior
# 7364           1      F                     Hispanic             Junior
# 7365           1      F                     Hispanic             Junior
# 7366           1      F                     Hispanic             Junior
# 7367           1      F                     Hispanic             Junior
#
#       first_generation  urm       first_language  \
# 0                  0.0  0.0         English only
# 1                  0.0  0.0         English only
# 2                  0.0  0.0         English only
# 3                  0.0  0.0         English only
# 4                  0.0  0.0         English only
# ...                ...  ...                  ...
# 7363               1.0  1.0  English/non-English
# 7364               1.0  1.0  English/non-English
# 7365               1.0  1.0  English/non-English
# 7366               1.0  1.0  English/non-English
# 7367               1.0  1.0  English/non-English
#
#                                             ethnicity_y  diversity
# 0     [Unknown / declined to state, Asian / Asian Am...          3
# 1     [Unknown / declined to state, Asian / Asian Am...          3
# 2     [Unknown / declined to state, Asian / Asian Am...          3
# 3     [Unknown / declined to state, Asian / Asian Am...          3
# 4     [Unknown / declined to state, Asian / Asian Am...          3
# ...                                                 ...        ...
# 7363             [Hispanic, nan, International student]          3
# 7364             [Hispanic, nan, International student]          3
# 7365             [Hispanic, nan, International student]          3
# 7366             [Hispanic, nan, International student]          3
# 7367             [Hispanic, nan, International student]          3
#
# [7368 rows x 19 columns]

# %%
data.groupby(['diversity'])['Primary code '].value_counts()[1]
# Out:
# Primary code
# SSI     78
# SMC     63
# SESU    46
# SN      35
# CRF     30
# CE      14
# CM      12
# CP       1
# EM       1
# Name: Primary code , dtype: int64

# %%
fig = plt.figure(figsize=(5,7))
ax = fig.add_axes([0,0,1,1])
k = list(data.groupby(['diversity'])['Primary code '].value_counts()[1].index)
val = list(data.groupby(['diversity'])['Primary code '].value_counts()[1])
sns.barplot(k, val)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fig = plt.figure(figsize=(5,7))
ax = fig.add_axes([0,0,1,1])
k = list(data.groupby(['diversity'])['Primary code '].value_counts()[2].index)
val = list(data.groupby(['diversity'])['Primary code '].value_counts()[2])
sns.barplot(k, val)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fig = plt.figure(figsize=(5,7))
ax = fig.add_axes([0,0,1,1])
k = list(data.groupby(['diversity'])['Primary code '].value_counts()[3].index)
val = list(data.groupby(['diversity'])['Primary code '].value_counts()[3])
sns.barplot(k, val)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fig = plt.figure(figsize=(5,7))
ax = fig.add_axes([0,0,1,1])
k = list(data.groupby(['diversity'])['Primary code '].value_counts()[4].index)
val = list(data.groupby(['diversity'])['Primary code '].value_counts()[4])
sns.barplot(k, val)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data = data[data['Primary code '] != 'EM']
data = data[data['Primary code '] != 'TD']

# %%
df2 = (data.groupby(['session_id', 'diversity']).agg({'Primary code ': 'value_counts'}).unstack(fill_value=0)).groupby('diversity').agg('mean')

# %%
df2
# Out:
#               Primary code                                                     \
# Primary code             CE        CM        CP       CRF      SESU       SMC
# diversity
# 1                  0.050179  0.043011  0.003584  0.107527  0.164875  0.225806
# 2                  0.057197  0.054814  0.002860  0.058151  0.169685  0.174452
# 3                  0.062437  0.052792  0.005330  0.090355  0.166244  0.123096
# 4                  0.057915  0.053089  0.009653  0.085907  0.146718  0.243243
#
#
# Primary code         SN       SSI
# diversity
# 1              0.125448  0.279570
# 2              0.119161  0.363680
# 3              0.124873  0.374873
# 4              0.094595  0.308880

# %%
for i in [0, 1, 2, 3]:
    df2.iloc[i] = df2.iloc[i]/df2.iloc[i].sum()

# %%
df2.plot.bar(figsize = (10,10))
# Out:
# <AxesSubplot:xlabel='diversity'>

# %%
data
# Out:
#       Unnamed: 0       session_id mellon_id  \
# 0              0  7298_PartyVenue    173442
# 1              1  7298_PartyVenue    173442
# 2              2  7298_PartyVenue    173442
# 3              3  7298_PartyVenue    173442
# 4              4  7298_PartyVenue    173442
# ...          ...              ...       ...
# 7363        7363   7371_candidate    187876
# 7364        7364   7371_candidate    187876
# 7365        7365   7371_candidate    187876
# 7366        7366   7371_candidate    187876
# 7367        7367   7371_candidate    187876
#
#                                               player_id  \
# 0     {'userID1': '202618', 'nickname1': 'bean boi',...
# 1     {'userID1': '202618', 'nickname1': 'bean boi',...
# 2     {'userID1': '202618', 'nickname1': 'bean boi',...
# 3     {'userID1': '202618', 'nickname1': 'bean boi',...
# 4     {'userID1': '202618', 'nickname1': 'bean boi',...
# ...                                                 ...
# 7363  {'userID1': '187876', 'nickname1': 'Sabrina', ...
# 7364  {'userID1': '187876', 'nickname1': 'Sabrina', ...
# 7365  {'userID1': '187876', 'nickname1': 'Sabrina', ...
# 7366  {'userID1': '187876', 'nickname1': 'Sabrina', ...
# 7367  {'userID1': '187876', 'nickname1': 'Sabrina', ...
#
#                                            event_result        task  \
# 0                                        what's up lads  PartyVenue
# 1                               bean boi i like ur name  PartyVenue
# 2                                   also mood alice lol  PartyVenue
# 3     question when u guys were signing up on the su...  PartyVenue
# 4                                RIGHT? ok im not crazy  PartyVenue
# ...                                                 ...         ...
# 7363                   I put BCA what did you guys put?   candidate
# 7364                                                yes   candidate
# 7365                                               yeah   candidate
# 7366  A has fewer character qualities than the other...   candidate
# 7367                      we can then all agree on BCA?   candidate
#
#      Primary code   revise_score  high_performance  female_members  \
# 0              SMC           0.0                 0               4
# 1              SMC           0.0                 0               4
# 2              SMC           0.0                 0               4
# 3              SMC           0.0                 0               4
# 4              SMC           0.0                 0               4
# ...            ...           ...               ...             ...
# 7363           SSI           0.0                 0               3
# 7364          SESU           0.0                 0               3
# 7365            SN           0.0                 0               3
# 7366           SSI           0.0                 0               3
# 7367            CM           0.0                 0               3
#
#       female_maj gender                    ethnicity application_status  \
# 0              1      F  Unknown / declined to state          Sophomore
# 1              1      F  Unknown / declined to state          Sophomore
# 2              1      F  Unknown / declined to state          Sophomore
# 3              1      F  Unknown / declined to state          Sophomore
# 4              1      F  Unknown / declined to state          Sophomore
# ...          ...    ...                          ...                ...
# 7363           1      F                     Hispanic             Junior
# 7364           1      F                     Hispanic             Junior
# 7365           1      F                     Hispanic             Junior
# 7366           1      F                     Hispanic             Junior
# 7367           1      F                     Hispanic             Junior
#
#       first_generation  urm       first_language
# 0                  0.0  0.0         English only
# 1                  0.0  0.0         English only
# 2                  0.0  0.0         English only
# 3                  0.0  0.0         English only
# 4                  0.0  0.0         English only
# ...                ...  ...                  ...
# 7363               1.0  1.0  English/non-English
# 7364               1.0  1.0  English/non-English
# 7365               1.0  1.0  English/non-English
# 7366               1.0  1.0  English/non-English
# 7367               1.0  1.0  English/non-English
#
# [7368 rows x 17 columns]

# %%
fig = plt.figure(figsize=(5,7))
ax = fig.add_axes([0,0,1,1])
k = list(data.groupby(['first_language'])['Primary code '].value_counts().index)
val = list(data.groupby(['first_language'])['Primary code '].value_counts())
sns.barplot(k, val)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-2c6f1f07f759> in <module>
#       3 k = list(data.groupby(['first_language'])['Primary code '].value_counts().index)
#       4 val = list(data.groupby(['first_language'])['Primary code '].value_counts())
# ----> 5 sns.barplot(k, val)
#       6 plt.show()
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3177 ):
#    3178
# -> 3179     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3180                           estimator, ci, n_boot, units, seed,
#    3181                           orient, color, palette, saturation,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1582                  errwidth, capsize, dodge):
#    1583         """Initialize the plotter."""
# -> 1584         self.establish_variables(x, y, hue, data, orient,
#    1585                                  order, hue_order, units)
#    1586         self.establish_colors(color, palette, saturation)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     204
#     205                 # Group the numeric data
# --> 206                 plot_data, value_label = self._group_longform(vals, groups,
#     207                                                               group_names)
#     208
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/categorical.py in _group_longform(self, vals, grouper, order)
#     251
#     252         # Group the val data
# --> 253         grouped_vals = vals.groupby(grouper)
#     254         out_data = []
#     255         for g in order:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/series.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    1689         axis = self._get_axis_number(axis)
#    1690
# -> 1691         return SeriesGroupBy(
#    1692             obj=self,
#    1693             keys=by,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     558             from pandas.core.groupby.grouper import get_grouper
#     559
# --> 560             grouper, exclusions, obj = get_grouper(
#     561                 obj,
#     562                 keys,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     809                 in_axis, name, level, gpr = False, None, gpr, None
#     810             else:
# --> 811                 raise KeyError(gpr)
#     812         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     813             # Add key to exclusions
#
# KeyError: ('English only', 'SSI')

# %%
data['first_language'].value_counts()/data.groupby('mellon_id')['first_language'].max().value_counts()
# Out:
# English only           15.908451
# English/non-English    14.923077
# Non-English            11.855263
# Name: first_language, dtype: float64

# %%
data.groupby('mellon_id')['first_language'].max().value_counts()
# Out:
# English/non-English    208
# Non-English            152
# English only           142
# Name: first_language, dtype: int64

# %%
data['first_language'].value_counts()
# Out:
# English/non-English    3104
# English only           2259
# Non-English            1802
# Name: first_language, dtype: int64

# %%
fig = plt.figure(figsize=(5,7))
ax = fig.add_axes([0,0,1,1])
k = list((data['first_language'].value_counts()/data.groupby('mellon_id')['first_language'].max().value_counts()).index)
val = list(data['first_language'].value_counts()/data.groupby('mellon_id')['first_language'].max().value_counts())
sns.barplot(k, val)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
