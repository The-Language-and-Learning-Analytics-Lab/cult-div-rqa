# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('./data/CPS_Chat_Data_F19_20200129.xlsx - uci_data_collection_completed_a.csv')

# %%
data = data[data.event_name == 'chat']

# %%
data.columns
# Out:
# Index(['session_id', 'team_id (mellon_id)', 'player_id', 'attempt_id',
#        'session_ext_data', 'event_name', 'event_start_time', 'event_end_time',
#        'event_by', 'event_to', 'event_result', 'event_location',
#        'event_ext_data', 'session_time', 'task'],
#       dtype='object')

# %%
coded_data = pd.read_csv('./data/Master Coded Data.xlsx - Chats.csv')

# %%
coded_data.columns
# Out:
# Index(['task', 'team_id', 'Person-ID (mellon-ID)', 'event_start_time',
#        'event_end_time', 'event_result', 'Primary code ', 'Primary Sub-code',
#        'Secondary Code', 'Secondary  Sub-code', 'Apartment Feature 1',
#        'Apartment Feature 2', 'Apartment Feature 3', 'Apartment Feature 4 ',
#        'Candidate Feature 1', 'Candidate Feature 2', 'Candidate Feature 3',
#        'Candidate Feature 4', 'Party Venue Feature 1', 'Party Venue Feature 2',
#        'Party Venue Feature 3', 'Party Venue Feature 4', 'Professor Feature 1',
#        'Professor Feature 2', 'Professor Feature 3', 'Professor Feature 4'],
#       dtype='object')

# %%
coded_data = coded_data.rename(columns={'Person-ID (mellon-ID)' : 'mellon_id'})
data = data.rename(columns={'event_by' : 'mellon_id', 'team_id (mellon_id)':'team_id'})

# %%
coded_data
# Out:
#            task                      team_id mellon_id  \
# 0     apartment  179706_162850_162936_182908    162850
# 1     apartment  179706_162850_162936_182908    182908
# 2     apartment  179706_162850_162936_182908    162936
# 3     apartment  179706_162850_162936_182908    179706
# 4     apartment  179706_162850_162936_182908    162850
# ...         ...                          ...       ...
# 7706  Candidate  190690_163721_178949_190068    186557
# 7707  Candidate  190690_163721_178949_190069    186557
# 7708  Candidate  190690_163721_178949_190070    165170
# 7709  Candidate  190690_163721_178949_190071    190696
# 7710  Candidate  190690_163721_178949_190072    183614
#
#                event_start_time             event_end_time       event_result  \
# 0     2019-09-28 17:14:21+00:00  2019-09-28 17:14:21+00:00                 Hi
# 1     2019-09-28 17:14:39+00:00  2019-09-28 17:14:39+00:00                hey
# 2     2019-09-28 17:14:47+00:00  2019-09-28 17:14:47+00:00                Hey
# 3     2019-09-28 17:14:48+00:00  2019-09-28 17:14:48+00:00               hola
# 4     2019-09-28 17:14:56+00:00  2019-09-28 17:14:56+00:00  Is everyone here?
# ...                         ...                        ...                ...
# 7706  2019-10-01 23:38:41+00:00                        NaN                 so
# 7707  2019-10-01 23:38:43+00:00                        NaN               CBA?
# 7708  2019-10-01 23:38:46+00:00                        NaN               yeah
# 7709  2019-10-01 23:38:48+00:00                        NaN       I believe so
# 7710  2019-10-01 23:38:53+00:00                        NaN             yes :)
#
#      Primary code  Primary Sub-code Secondary Code Secondary  Sub-code  ...  \
# 0              SMC            SMC-R            NaN                 NaN  ...
# 1              SMC            SMC-R            NaN                 NaN  ...
# 2              SMC            SMC-R            NaN                 NaN  ...
# 3              SMC            SMC-R            NaN                 NaN  ...
# 4               CM             CM-G            NaN                 NaN  ...
# ...            ...              ...            ...                 ...  ...
# 7706           SSI            SSI-U            NaN                 NaN  ...
# 7707            CM             CM-S            NaN                 NaN  ...
# 7708            SN             SN-A            NaN                 NaN  ...
# 7709          SESU           SESU-A            NaN                 NaN  ...
# 7710            SN             SN-A            NaN                 NaN  ...
#
#      Candidate Feature 3 Candidate Feature 4 Party Venue Feature 1  \
# 0                    NaN                 NaN                   NaN
# 1                    NaN                 NaN                   NaN
# 2                    NaN                 NaN                   NaN
# 3                    NaN                 NaN                   NaN
# 4                    NaN                 NaN                   NaN
# ...                  ...                 ...                   ...
# 7706                 NaN                 NaN                   NaN
# 7707                 NaN                 NaN                   NaN
# 7708                 NaN                 NaN                   NaN
# 7709                 NaN                 NaN                   NaN
# 7710                 NaN                 NaN                   NaN
#
#      Party Venue Feature 2 Party Venue Feature 3 Party Venue Feature 4  \
# 0                      NaN                   NaN                   NaN
# 1                      NaN                   NaN                   NaN
# 2                      NaN                   NaN                   NaN
# 3                      NaN                   NaN                   NaN
# 4                      NaN                   NaN                   NaN
# ...                    ...                   ...                   ...
# 7706                   NaN                   NaN                   NaN
# 7707                   NaN                   NaN                   NaN
# 7708                   NaN                   NaN                   NaN
# 7709                   NaN                   NaN                   NaN
# 7710                   NaN                   NaN                   NaN
#
#      Professor Feature 1 Professor Feature 2 Professor Feature 3  \
# 0                    NaN                 NaN                 NaN
# 1                    NaN                 NaN                 NaN
# 2                    NaN                 NaN                 NaN
# 3                    NaN                 NaN                 NaN
# 4                    NaN                 NaN                 NaN
# ...                  ...                 ...                 ...
# 7706                 NaN                 NaN                 NaN
# 7707                 NaN                 NaN                 NaN
# 7708                 NaN                 NaN                 NaN
# 7709                 NaN                 NaN                 NaN
# 7710                 NaN                 NaN                 NaN
#
#      Professor Feature 4
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 7706                 NaN
# 7707                 NaN
# 7708                 NaN
# 7709                 NaN
# 7710                 NaN
#
# [7711 rows x 26 columns]

# %%
merged_data = data.merge(coded_data[['mellon_id', 'event_result', 'event_start_time', 'event_end_time', 'Primary code ']], on = ['mellon_id', 'event_result', 'event_start_time', 'event_end_time'], how = 'left')

# %%
merged_data[merged_data.isna().any(axis=1)]
# Out:
#            session_id                        team_id  \
# 0      7343_apartment
# 10    7298_PartyVenue    163093_164591_173442_202618
# 19    7298_PartyVenue    163093_164591_173442_202618
# 30    7298_PartyVenue    163093_164591_173442_202618
# 33    7298_PartyVenue    163093_164591_173442_202618
# ...               ...                            ...
# 3662   7376_apartment  179016_191341_C@ss3tte_194334
# 3675   7376_apartment  179016_191341_C@ss3tte_194334
# 3677   7376_apartment  179016_191341_C@ss3tte_194334
# 3681   7376_apartment  179016_191341_C@ss3tte_194334
# 5585  7348_PartyVenue    190566_201352_185680_194531
#
#                                               player_id  attempt_id  \
# 0     {'userID1': '163929', 'nickname1': 'jessica', ...           1
# 10    {'userID1': '202618', 'nickname1': 'bean boi',...           1
# 19    {'userID1': '202618', 'nickname1': 'bean boi',...           1
# 30    {'userID1': '202618', 'nickname1': 'bean boi',...           1
# 33    {'userID1': '202618', 'nickname1': 'bean boi',...           1
# ...                                                 ...         ...
# 3662  {'userID1': '179016', 'nickname1': 'Blair', 'u...           1
# 3675  {'userID1': '179016', 'nickname1': 'Blair', 'u...           1
# 3677  {'userID1': '179016', 'nickname1': 'Blair', 'u...           1
# 3681  {'userID1': '179016', 'nickname1': 'Blair', 'u...           1
# 5585  {'userID1': '190566', 'nickname1': 'Adrian', '...           1
#
#                                        session_ext_data event_name  \
# 0     {'attempt': '1', 'n_player': '4', 'team_assemb...       chat
# 10    {'attempt': '1', 'n_player': '4', 'team_assemb...       chat
# 19    {'attempt': '1', 'n_player': '4', 'team_assemb...       chat
# 30    {'attempt': '1', 'n_player': '4', 'team_assemb...       chat
# 33    {'attempt': '1', 'n_player': '4', 'team_assemb...       chat
# ...                                                 ...        ...
# 3662  {'attempt': '1', 'n_player': '4', 'team_assemb...       chat
# 3675  {'attempt': '1', 'n_player': '4', 'team_assemb...       chat
# 3677  {'attempt': '1', 'n_player': '4', 'team_assemb...       chat
# 3681  {'attempt': '1', 'n_player': '4', 'team_assemb...       chat
# 5585  {'attempt': '1', 'n_player': '4', 'team_assemb...       chat
#
#                event_start_time             event_end_time mellon_id event_to  \
# 0     2019-09-28 17:12:43+00:00  2019-09-28 17:12:43+00:00    163793   others
# 10    2019-09-28 17:12:12+00:00  2019-09-28 17:12:12+00:00    202618   others
# 19    2019-09-28 17:12:49+00:00  2019-09-28 17:12:49+00:00    173442   others
# 30    2019-09-28 17:13:56+00:00  2019-09-28 17:13:56+00:00    173442   others
# 33    2019-09-28 17:14:09+00:00  2019-09-28 17:14:09+00:00    173442   others
# ...                         ...                        ...       ...      ...
# 3662  2019-09-28 21:17:30+00:00  2019-09-28 21:17:30+00:00    179016   others
# 3675  2019-09-28 21:19:30+00:00  2019-09-28 21:19:30+00:00    194334   others
# 3677  2019-09-28 21:19:39+00:00  2019-09-28 21:19:39+00:00    194334   others
# 3681  2019-09-28 21:19:56+00:00  2019-09-28 21:19:56+00:00    194334   others
# 5585  2019-10-07 16:25:42+00:00  2019-10-07 16:25:42+00:00    201352   others
#
#                                            event_result event_location  \
# 0                                       Hello everyone!   slide0-step0
# 10                                            yeah lol    slide0-step0
# 19                                               aight    slide0-step0
# 30    there's only 2 min left on the intro page anyways   slide0-step0
# 33                               click the next button    slide0-step0
# ...                                                 ...            ...
# 3662  because of the 24 hr maintenance thing and ove...   slide2-step0
# 3675                                            Maybe?    slide2-step0
# 3677                                     Yeah same BAC    slide2-step0
# 3681                              we're with you then!    slide2-step0
# 5585                                             10-Oct   slide2-step0
#
#      event_ext_data  session_time        task Primary code
# 0                {}             0   apartment           NaN
# 10               {}            54  PartyVenue           NaN
# 19               {}            91  PartyVenue           NaN
# 30               {}           158  PartyVenue           NaN
# 33               {}           171  PartyVenue           NaN
# ...             ...           ...         ...           ...
# 3662             {}           278   apartment           NaN
# 3675             {}           398   apartment           NaN
# 3677             {}           407   apartment           NaN
# 3681             {}           424   apartment           NaN
# 5585             {}           800  PartyVenue           NaN
#
# [391 rows x 16 columns]

# %%
merged_data_clean = merged_data.dropna()

# %%
scores = pd.read_csv('./data/CPS_scores.csv')

# %%
merged_data_clean_scores = merged_data_clean.merge(scores[['mellon_id','revise_score']], on=['mellon_id'], how = 'inner')

# %%
merged_data_clean_scores
# Out:
#            session_id                        team_id  \
# 0     7298_PartyVenue    163093_164591_173442_202618
# 1     7298_PartyVenue    163093_164591_173442_202618
# 2     7298_PartyVenue    163093_164591_173442_202618
# 3     7298_PartyVenue    163093_164591_173442_202618
# 4     7298_PartyVenue    163093_164591_173442_202618
# ...               ...                            ...
# 7363   7371_candidate  Isabella_195466_187876_180275
# 7364   7371_candidate  Isabella_195466_187876_180275
# 7365   7371_candidate  Isabella_195466_187876_180275
# 7366   7371_candidate  Isabella_195466_187876_180275
# 7367   7371_candidate  Isabella_195466_187876_180275
#
#                                               player_id  attempt_id  \
# 0     {'userID1': '202618', 'nickname1': 'bean boi',...           1
# 1     {'userID1': '202618', 'nickname1': 'bean boi',...           1
# 2     {'userID1': '202618', 'nickname1': 'bean boi',...           1
# 3     {'userID1': '202618', 'nickname1': 'bean boi',...           1
# 4     {'userID1': '202618', 'nickname1': 'bean boi',...           1
# ...                                                 ...         ...
# 7363  {'userID1': '187876', 'nickname1': 'Sabrina', ...           1
# 7364  {'userID1': '187876', 'nickname1': 'Sabrina', ...           1
# 7365  {'userID1': '187876', 'nickname1': 'Sabrina', ...           1
# 7366  {'userID1': '187876', 'nickname1': 'Sabrina', ...           1
# 7367  {'userID1': '187876', 'nickname1': 'Sabrina', ...           1
#
#                                        session_ext_data event_name  \
# 0     {'attempt': '1', 'n_player': '4', 'team_assemb...       chat
# 1     {'attempt': '1', 'n_player': '4', 'team_assemb...       chat
# 2     {'attempt': '1', 'n_player': '4', 'team_assemb...       chat
# 3     {'attempt': '1', 'n_player': '4', 'team_assemb...       chat
# 4     {'attempt': '1', 'n_player': '4', 'team_assemb...       chat
# ...                                                 ...        ...
# 7363  {'attempt': '1', 'n_player': '4', 'team_assemb...       chat
# 7364  {'attempt': '1', 'n_player': '4', 'team_assemb...       chat
# 7365  {'attempt': '1', 'n_player': '4', 'team_assemb...       chat
# 7366  {'attempt': '1', 'n_player': '4', 'team_assemb...       chat
# 7367  {'attempt': '1', 'n_player': '4', 'team_assemb...       chat
#
#                event_start_time             event_end_time mellon_id event_to  \
# 0     2019-09-28 17:11:18+00:00  2019-09-28 17:11:18+00:00    173442   others
# 1     2019-09-28 17:11:32+00:00  2019-09-28 17:11:32+00:00    173442   others
# 2     2019-09-28 17:11:39+00:00  2019-09-28 17:11:39+00:00    173442   others
# 3     2019-09-28 17:12:03+00:00  2019-09-28 17:12:03+00:00    173442   others
# 4     2019-09-28 17:12:19+00:00  2019-09-28 17:12:19+00:00    173442   others
# ...                         ...                        ...       ...      ...
# 7363  2019-10-03 23:11:56+00:00  2019-10-03 23:11:56+00:00    187876   others
# 7364  2019-10-03 23:13:17+00:00  2019-10-03 23:13:17+00:00    187876   others
# 7365  2019-10-03 23:14:32+00:00  2019-10-03 23:14:32+00:00    187876   others
# 7366  2019-10-03 23:17:55+00:00  2019-10-03 23:17:55+00:00    187876   others
# 7367  2019-10-03 23:18:33+00:00  2019-10-03 23:18:33+00:00    187876   others
#
#                                            event_result event_location  \
# 0                                        what's up lads   slide0-step0
# 1                               bean boi i like ur name   slide0-step0
# 2                                   also mood alice lol   slide0-step0
# 3     question when u guys were signing up on the su...   slide0-step0
# 4                                RIGHT? ok im not crazy   slide0-step0
# ...                                                 ...            ...
# 7363                   I put BCA what did you guys put?   slide2-step0
# 7364                                                yes   slide2-step0
# 7365                                               yeah   slide2-step0
# 7366  A has fewer character qualities than the other...   slide2-step0
# 7367                      we can then all agree on BCA?   slide2-step0
#
#      event_ext_data  session_time        task Primary code   revise_score
# 0                {}             0  PartyVenue           SMC             0
# 1                {}            14  PartyVenue           SMC             0
# 2                {}            21  PartyVenue           SMC             0
# 3                {}            45  PartyVenue           SMC             0
# 4                {}            61  PartyVenue           SMC             0
# ...             ...           ...         ...           ...           ...
# 7363             {}           312   candidate           SSI             0
# 7364             {}           393   candidate          SESU             0
# 7365             {}           468   candidate            SN             0
# 7366             {}           671   candidate           SSI             0
# 7367             {}           709   candidate            CM             0
#
# [7368 rows x 17 columns]

# %%
d1 = merged_data_clean_scores.groupby(by=['session_id', 'mellon_id'], as_index=False).agg({'revise_score': 'mean'})

# %%
d2 = d1.groupby(by=['session_id'], as_index=False).agg({'revise_score': 'mean'})

# %%
d2
# Out:
#          session_id  revise_score
# 0    7283_Professor          0.00
# 1    7285_Professor          0.00
# 2    7287_Professor          0.00
# 3    7288_Professor          0.00
# 4    7289_Professor          0.00
# ..              ...           ...
# 124  7376_apartment          0.25
# 125  7377_apartment          0.00
# 126  7378_apartment          1.00
# 127  7380_apartment          2.00
# 128  7388_apartment          1.00
#
# [129 rows x 2 columns]

# %%
merged_data_clean_scores
# Out:
#            session_id                        team_id  \
# 0     7298_PartyVenue    163093_164591_173442_202618
# 1     7298_PartyVenue    163093_164591_173442_202618
# 2     7298_PartyVenue    163093_164591_173442_202618
# 3     7298_PartyVenue    163093_164591_173442_202618
# 4     7298_PartyVenue    163093_164591_173442_202618
# ...               ...                            ...
# 7363   7371_candidate  Isabella_195466_187876_180275
# 7364   7371_candidate  Isabella_195466_187876_180275
# 7365   7371_candidate  Isabella_195466_187876_180275
# 7366   7371_candidate  Isabella_195466_187876_180275
# 7367   7371_candidate  Isabella_195466_187876_180275
#
#                                               player_id  attempt_id  \
# 0     {'userID1': '202618', 'nickname1': 'bean boi',...           1
# 1     {'userID1': '202618', 'nickname1': 'bean boi',...           1
# 2     {'userID1': '202618', 'nickname1': 'bean boi',...           1
# 3     {'userID1': '202618', 'nickname1': 'bean boi',...           1
# 4     {'userID1': '202618', 'nickname1': 'bean boi',...           1
# ...                                                 ...         ...
# 7363  {'userID1': '187876', 'nickname1': 'Sabrina', ...           1
# 7364  {'userID1': '187876', 'nickname1': 'Sabrina', ...           1
# 7365  {'userID1': '187876', 'nickname1': 'Sabrina', ...           1
# 7366  {'userID1': '187876', 'nickname1': 'Sabrina', ...           1
# 7367  {'userID1': '187876', 'nickname1': 'Sabrina', ...           1
#
#                                        session_ext_data event_name  \
# 0     {'attempt': '1', 'n_player': '4', 'team_assemb...       chat
# 1     {'attempt': '1', 'n_player': '4', 'team_assemb...       chat
# 2     {'attempt': '1', 'n_player': '4', 'team_assemb...       chat
# 3     {'attempt': '1', 'n_player': '4', 'team_assemb...       chat
# 4     {'attempt': '1', 'n_player': '4', 'team_assemb...       chat
# ...                                                 ...        ...
# 7363  {'attempt': '1', 'n_player': '4', 'team_assemb...       chat
# 7364  {'attempt': '1', 'n_player': '4', 'team_assemb...       chat
# 7365  {'attempt': '1', 'n_player': '4', 'team_assemb...       chat
# 7366  {'attempt': '1', 'n_player': '4', 'team_assemb...       chat
# 7367  {'attempt': '1', 'n_player': '4', 'team_assemb...       chat
#
#                event_start_time             event_end_time mellon_id event_to  \
# 0     2019-09-28 17:11:18+00:00  2019-09-28 17:11:18+00:00    173442   others
# 1     2019-09-28 17:11:32+00:00  2019-09-28 17:11:32+00:00    173442   others
# 2     2019-09-28 17:11:39+00:00  2019-09-28 17:11:39+00:00    173442   others
# 3     2019-09-28 17:12:03+00:00  2019-09-28 17:12:03+00:00    173442   others
# 4     2019-09-28 17:12:19+00:00  2019-09-28 17:12:19+00:00    173442   others
# ...                         ...                        ...       ...      ...
# 7363  2019-10-03 23:11:56+00:00  2019-10-03 23:11:56+00:00    187876   others
# 7364  2019-10-03 23:13:17+00:00  2019-10-03 23:13:17+00:00    187876   others
# 7365  2019-10-03 23:14:32+00:00  2019-10-03 23:14:32+00:00    187876   others
# 7366  2019-10-03 23:17:55+00:00  2019-10-03 23:17:55+00:00    187876   others
# 7367  2019-10-03 23:18:33+00:00  2019-10-03 23:18:33+00:00    187876   others
#
#                                            event_result event_location  \
# 0                                        what's up lads   slide0-step0
# 1                               bean boi i like ur name   slide0-step0
# 2                                   also mood alice lol   slide0-step0
# 3     question when u guys were signing up on the su...   slide0-step0
# 4                                RIGHT? ok im not crazy   slide0-step0
# ...                                                 ...            ...
# 7363                   I put BCA what did you guys put?   slide2-step0
# 7364                                                yes   slide2-step0
# 7365                                               yeah   slide2-step0
# 7366  A has fewer character qualities than the other...   slide2-step0
# 7367                      we can then all agree on BCA?   slide2-step0
#
#      event_ext_data  session_time        task Primary code   revise_score
# 0                {}             0  PartyVenue           SMC             0
# 1                {}            14  PartyVenue           SMC             0
# 2                {}            21  PartyVenue           SMC             0
# 3                {}            45  PartyVenue           SMC             0
# 4                {}            61  PartyVenue           SMC             0
# ...             ...           ...         ...           ...           ...
# 7363             {}           312   candidate           SSI             0
# 7364             {}           393   candidate          SESU             0
# 7365             {}           468   candidate            SN             0
# 7366             {}           671   candidate           SSI             0
# 7367             {}           709   candidate            CM             0
#
# [7368 rows x 17 columns]

# %%
d3 = merged_data_clean_scores[['session_id', 'mellon_id', 'player_id', 'event_result', 'task', 'Primary code ']].merge(d2, on = ['session_id'])

# %%
mean = np.mean(d3['revise_score'])
high_perf = (d3['revise_score'] > mean).astype(int)

# %%
d3['high_performance'] = high_perf

# %%
# Out:
#            session_id mellon_id  \
# 0     7298_PartyVenue    173442
# 1     7298_PartyVenue    173442
# 2     7298_PartyVenue    173442
# 3     7298_PartyVenue    173442
# 4     7298_PartyVenue    173442
# ...               ...       ...
# 7363   7371_candidate    187876
# 7364   7371_candidate    187876
# 7365   7371_candidate    187876
# 7366   7371_candidate    187876
# 7367   7371_candidate    187876
#
#                                               player_id  \
# 0     {'userID1': '202618', 'nickname1': 'bean boi',...
# 1     {'userID1': '202618', 'nickname1': 'bean boi',...
# 2     {'userID1': '202618', 'nickname1': 'bean boi',...
# 3     {'userID1': '202618', 'nickname1': 'bean boi',...
# 4     {'userID1': '202618', 'nickname1': 'bean boi',...
# ...                                                 ...
# 7363  {'userID1': '187876', 'nickname1': 'Sabrina', ...
# 7364  {'userID1': '187876', 'nickname1': 'Sabrina', ...
# 7365  {'userID1': '187876', 'nickname1': 'Sabrina', ...
# 7366  {'userID1': '187876', 'nickname1': 'Sabrina', ...
# 7367  {'userID1': '187876', 'nickname1': 'Sabrina', ...
#
#                                            event_result        task  \
# 0                                        what's up lads  PartyVenue
# 1                               bean boi i like ur name  PartyVenue
# 2                                   also mood alice lol  PartyVenue
# 3     question when u guys were signing up on the su...  PartyVenue
# 4                                RIGHT? ok im not crazy  PartyVenue
# ...                                                 ...         ...
# 7363                   I put BCA what did you guys put?   candidate
# 7364                                                yes   candidate
# 7365                                               yeah   candidate
# 7366  A has fewer character qualities than the other...   candidate
# 7367                      we can then all agree on BCA?   candidate
#
#      Primary code   revise_score  high_performance
# 0              SMC           0.0                 0
# 1              SMC           0.0                 0
# 2              SMC           0.0                 0
# 3              SMC           0.0                 0
# 4              SMC           0.0                 0
# ...            ...           ...               ...
# 7363           SSI           0.0                 0
# 7364          SESU           0.0                 0
# 7365            SN           0.0                 0
# 7366           SSI           0.0                 0
# 7367            CM           0.0                 0
#
# [7368 rows x 8 columns]

# %%
groups = d3.groupby(by=['session_id'])['mellon_id'].unique()

# %%
b['7371_candidate']
# Out:
# array(['195466', 'Isabella', '180275', '187876'], dtype=object)

# %%
background = pd.read_csv('./data/Mellondemographic_Student_20200205.csv')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3155: DtypeWarning: Columns (5,13,14,16,18,170) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
background.columns
# Out:
# Index(['student_sid', 'mellon_id', 'group_a', 'mellon_enr_dt_a', 'group_b',
#        'mellon_enr_dt_b', 'birth_year', 'birth_month', 'gender', 'citizenship',
#        ...
#        'levelcd', 'pascd', 'tascd', 'honors', 'admitdate',
#        'entry_units_completed_transfer', 'curr_units_completed_transfer',
#        'current_ind', 'eff_start_dt', 'eff_end_dt'],
#       dtype='object', length=180)

# %%
female = []
fm = []
non_int = ['wendy6', 'Ratlife2001', 'Isabella', 'juarezm', 'jennajyee', 'Santa@na2019', 'ucinetid', 'zotzot', 'C@ss3tte']
for i in d3.session_id:
    s = 0
    members = groups[i]
    for j in members:
        if j in non_int:
            continue
        g = background[background.mellon_id == int(j)]['gender'].any()
        if g == 'F':
            s += 1
    female.append(s)
    fm.append(int(s>(len(members)/2)))

# %%
d3['female_members'] = female
d3['female_maj'] = fm

# %%
d3
# Out:
#            session_id mellon_id  \
# 0     7298_PartyVenue    173442
# 1     7298_PartyVenue    173442
# 2     7298_PartyVenue    173442
# 3     7298_PartyVenue    173442
# 4     7298_PartyVenue    173442
# ...               ...       ...
# 7363   7371_candidate    187876
# 7364   7371_candidate    187876
# 7365   7371_candidate    187876
# 7366   7371_candidate    187876
# 7367   7371_candidate    187876
#
#                                               player_id  \
# 0     {'userID1': '202618', 'nickname1': 'bean boi',...
# 1     {'userID1': '202618', 'nickname1': 'bean boi',...
# 2     {'userID1': '202618', 'nickname1': 'bean boi',...
# 3     {'userID1': '202618', 'nickname1': 'bean boi',...
# 4     {'userID1': '202618', 'nickname1': 'bean boi',...
# ...                                                 ...
# 7363  {'userID1': '187876', 'nickname1': 'Sabrina', ...
# 7364  {'userID1': '187876', 'nickname1': 'Sabrina', ...
# 7365  {'userID1': '187876', 'nickname1': 'Sabrina', ...
# 7366  {'userID1': '187876', 'nickname1': 'Sabrina', ...
# 7367  {'userID1': '187876', 'nickname1': 'Sabrina', ...
#
#                                            event_result        task  \
# 0                                        what's up lads  PartyVenue
# 1                               bean boi i like ur name  PartyVenue
# 2                                   also mood alice lol  PartyVenue
# 3     question when u guys were signing up on the su...  PartyVenue
# 4                                RIGHT? ok im not crazy  PartyVenue
# ...                                                 ...         ...
# 7363                   I put BCA what did you guys put?   candidate
# 7364                                                yes   candidate
# 7365                                               yeah   candidate
# 7366  A has fewer character qualities than the other...   candidate
# 7367                      we can then all agree on BCA?   candidate
#
#      Primary code   revise_score  high_performance  female_members  female_maj
# 0              SMC           0.0                 0               4           1
# 1              SMC           0.0                 0               4           1
# 2              SMC           0.0                 0               4           1
# 3              SMC           0.0                 0               4           1
# 4              SMC           0.0                 0               4           1
# ...            ...           ...               ...             ...         ...
# 7363           SSI           0.0                 0               3           1
# 7364          SESU           0.0                 0               3           1
# 7365            SN           0.0                 0               3           1
# 7366           SSI           0.0                 0               3           1
# 7367            CM           0.0                 0               3           1
#
# [7368 rows x 10 columns]

# %%
d3.mellon_id = d3.mellon_id.astype(str)
background.mellon_id = background.mellon_id.astype(str)

# %%
d3.merge(background[['mellon_id', 'gender', 'ethnicity', 'application_status', 'first_generation', 'urm', 'first_language']], on = 'mellon_id', how = 'left').to_csv('final.csv')

# %%
d4 = pd.read_csv('final.csv')

# %%
d4
# Out:
#       Unnamed: 0       session_id mellon_id  \
# 0              0  7298_PartyVenue    173442
# 1              1  7298_PartyVenue    173442
# 2              2  7298_PartyVenue    173442
# 3              3  7298_PartyVenue    173442
# 4              4  7298_PartyVenue    173442
# ...          ...              ...       ...
# 7363        7363   7371_candidate    187876
# 7364        7364   7371_candidate    187876
# 7365        7365   7371_candidate    187876
# 7366        7366   7371_candidate    187876
# 7367        7367   7371_candidate    187876
#
#                                               player_id  \
# 0     {'userID1': '202618', 'nickname1': 'bean boi',...
# 1     {'userID1': '202618', 'nickname1': 'bean boi',...
# 2     {'userID1': '202618', 'nickname1': 'bean boi',...
# 3     {'userID1': '202618', 'nickname1': 'bean boi',...
# 4     {'userID1': '202618', 'nickname1': 'bean boi',...
# ...                                                 ...
# 7363  {'userID1': '187876', 'nickname1': 'Sabrina', ...
# 7364  {'userID1': '187876', 'nickname1': 'Sabrina', ...
# 7365  {'userID1': '187876', 'nickname1': 'Sabrina', ...
# 7366  {'userID1': '187876', 'nickname1': 'Sabrina', ...
# 7367  {'userID1': '187876', 'nickname1': 'Sabrina', ...
#
#                                            event_result        task  \
# 0                                        what's up lads  PartyVenue
# 1                               bean boi i like ur name  PartyVenue
# 2                                   also mood alice lol  PartyVenue
# 3     question when u guys were signing up on the su...  PartyVenue
# 4                                RIGHT? ok im not crazy  PartyVenue
# ...                                                 ...         ...
# 7363                   I put BCA what did you guys put?   candidate
# 7364                                                yes   candidate
# 7365                                               yeah   candidate
# 7366  A has fewer character qualities than the other...   candidate
# 7367                      we can then all agree on BCA?   candidate
#
#      Primary code   revise_score  high_performance  female_members  \
# 0              SMC           0.0                 0               4
# 1              SMC           0.0                 0               4
# 2              SMC           0.0                 0               4
# 3              SMC           0.0                 0               4
# 4              SMC           0.0                 0               4
# ...            ...           ...               ...             ...
# 7363           SSI           0.0                 0               3
# 7364          SESU           0.0                 0               3
# 7365            SN           0.0                 0               3
# 7366           SSI           0.0                 0               3
# 7367            CM           0.0                 0               3
#
#       female_maj gender                    ethnicity application_status  \
# 0              1      F  Unknown / declined to state          Sophomore
# 1              1      F  Unknown / declined to state          Sophomore
# 2              1      F  Unknown / declined to state          Sophomore
# 3              1      F  Unknown / declined to state          Sophomore
# 4              1      F  Unknown / declined to state          Sophomore
# ...          ...    ...                          ...                ...
# 7363           1      F                     Hispanic             Junior
# 7364           1      F                     Hispanic             Junior
# 7365           1      F                     Hispanic             Junior
# 7366           1      F                     Hispanic             Junior
# 7367           1      F                     Hispanic             Junior
#
#       first_generation  urm       first_language
# 0                  0.0  0.0         English only
# 1                  0.0  0.0         English only
# 2                  0.0  0.0         English only
# 3                  0.0  0.0         English only
# 4                  0.0  0.0         English only
# ...                ...  ...                  ...
# 7363               1.0  1.0  English/non-English
# 7364               1.0  1.0  English/non-English
# 7365               1.0  1.0  English/non-English
# 7366               1.0  1.0  English/non-English
# 7367               1.0  1.0  English/non-English
#
# [7368 rows x 17 columns]
